# %%
## IMPORT LIBRERIE ##

import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import numpy as np
from operator import itemgetter

# %%
## DEFINIZIONE VARIABILI ##

# CREDENZIALI
username_ = 'Di Febo FDS'
pwd_ = 'kTUha.D&,CN-is9'

# FISSE PER IL TEST
competition_to_search = 'SERIE A'
competition_dict = {'SERIE A':'2'}
season_to_search = 2022

# VARIABILI ANCHE PER IL TEST
player_to_search = 'CALABRIA'
team_to_search = 'MILAN'
opponent_to_search = 'UDINESE'
homeAwayFlag = 'HOME'

if homeAwayFlag == 'HOME':
    homeTeam = team_to_search
    awayTeam = opponent_to_search
else:
    awayTeam = team_to_search
    homeTeam = opponent_to_search

# %%
# CODICE PER CARLO ANNICCHIARICO

rankings_link = ' http://server.sics.it/livefeeds/x05.json?seasonId='+str(season_to_search)+'&competitionId='+str(competition_dict[competition_to_search])+'&lang=it'
rankings_json_data = requests.get(rankings_link, auth = HTTPBasicAuth(username_, pwd_)).json()

#rankings_json_data

# %%
# CODICE PER ROBERTO ANGIONI

player_link = ' http://server.sics.it/livefeeds/s02.json?seasonId='+str(season_to_search)+'&lang=it'
player_json_data = requests.get(player_link, auth = HTTPBasicAuth(username_, pwd_)).json()['player']

pd_players = pd.DataFrame(player_json_data)

pd_players
# Out:
#          id  firstName    lastName      knownName    bornDate  shirtNumber  \
# 0     41227      LEROY      ABANDA      ABANDA L.  2000-06-07            0
# 1     36104      JAMES    ABANKWAH    ABANKWAH J.  2004-01-16           14
# 2     20253     OLIVER  ABILDGAARD  ABILDGAARD O.  1996-06-10           28
# 3     12799      TAMMY     ABRAHAM     ABRAHAM T.  1997-10-02            9
# 4     27974  CHRISTIAN      ACELLA      ACELLA C.  2002-07-07           23
# ...     ...        ...         ...            ...         ...          ...
# 996   26714      PETAR       ZOVKO       ZOVKO P.  2002-03-25           40
# 997   31846        JAN     ZUBEREK     ZUBEREK J.  2004-03-13            0
# 998   23354   EMANUELE      ZUELLI      ZUELLI E.  2001-11-22            0
# 999   20277     SZYMON   ZURKOWSKI   ZURKOWSKI S.  1997-09-25           77
# 1000  20277     SZYMON   ZURKOWSKI   ZURKOWSKI S.  1997-09-25           27
#
#             position           citizenship  height      foot  \
# 0          Difensore               Francia   180.0  sinistro
# 1          Difensore               Irlanda   182.0    destro
# 2     Centrocampista             Danimarca   192.0  sinistro
# 3         Attaccante           Inghilterra   194.0    destro
# 4     Centrocampista                Italia     NaN    destro
# ...              ...                   ...     ...       ...
# 996         Portiere  Bosnia ed Erzegovina   192.0  sinistro
# 997       Attaccante               Polonia   188.0    destro
# 998   Centrocampista                Italia   179.0  entrambi
# 999   Centrocampista               Polonia   185.0    destro
# 1000  Centrocampista               Polonia   185.0    destro
#
#                                                   photo  module_position  \
# 0     https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 1     https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 2     https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 3     https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 4     https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# ...                                                 ...              ...
# 996   https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 997   https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 998   https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 999   https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
# 1000  https://s3.eu-west-1.amazonaws.com/it.sics.log...                0
#
#      position_detail contract_expires
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3     Punta centrale       2026-06-30
# 4           Centrale              NaN
# ...              ...              ...
# 996         Portiere       2024-06-30
# 997              NaN              NaN
# 998              NaN              NaN
# 999              NaN              NaN
# 1000        Centrale       2024-06-30
#
# [1001 rows x 14 columns]

# %%
## TROVA IL MATCH ID ##

link = 'http://server.sics.it/livefeeds/x16.json?seasonId='+str(season_to_search)+'&competitionId='+competition_dict[competition_to_search]+'&lang=it'

# JSON_data
# Making a get request
match_json_data = requests.get(link, auth = HTTPBasicAuth(username_, pwd_)).json()

#match_json_data
#match_json_data['matchData']
match_row = list(filter(lambda a : (a['homeTeam']['name'] == homeTeam) and (a['awayTeam']['name'] == awayTeam), match_json_data['matchData']))[0]

matchId = match_row['id']

print('MatchId: '+str(matchId))
# Out:
# MatchId: 33965

# %%
## TROVA IL TEAM ID ##

if homeAwayFlag == 'HOME':
    teamId = match_row['homeTeam']['id']
else:
    teamId = match_row['awayTeam']['id']

print('TeamId: '+str(teamId))
# Out:
# TeamId: 100

# %%
## TROVA LOGO SQUADRA PER TEAM ID ##

team_link = 'http://server.sics.it/livefeeds/s01.json?lang=it'
team_json_data = requests.get(team_link, auth = HTTPBasicAuth(username_, pwd_)).json()

#list(filter(lambda row : team_to_search in str(row['name']), team_json_data['teams']))['logo']
list(filter(lambda row : team_to_search in str(row['name']), team_json_data['teams']))[0]['logo']
# Out:
# 'https://s3.eu-west-1.amazonaws.com/it.sics.logo/72/teamlogo/milan.png'

# %%
## TROVA IL PLAYER ID ##

player_link = ' http://server.sics.it/livefeeds/s02.json?seasonId='+str(season_to_search)+'&teamId='+str(teamId)+'&lang=it'
player_json_data = requests.get(player_link, auth = HTTPBasicAuth(username_, pwd_)).json()

player_row = list(filter(lambda row: row['lastName'] == player_to_search, player_json_data['player']))[0]
playerId = player_row['id']

print('PlayerId: '+str(playerId))
# Out:
# PlayerId: 7811

# %%
## EXTRA: APRI URL FOTO GIOCATORE ##

import webbrowser

url = player_row['photo']

webbrowser.open(url)
# Out:
# True

# %%
## TROVA TUTTE LE PARTITE GIOCATE DAL PLAYER ID ##

games_player_link = ' http://server.sics.it/livefeeds/s03.json?seasonId='+str(season_to_search)+'&competitionId='+str(competition_dict[competition_to_search])+'&playerId='+str(playerId)+'&lang=it'
games_player_json_data = requests.get(games_player_link, auth = HTTPBasicAuth(username_, pwd_)).json()

games_player_json_data['matchData'][:2]
# Out:
# [{'id': 34339,
#   'date': '2023-06-04 21:00:00',
#   'matchday': 38,
#   'season': {'id': 2022, 'name': '2022-2023'},
#   'competition': {'id': 2, 'name': 'SERIE A'},
#   'homeTeam': {'id': 100, 'name': 'MILAN'},
#   'awayTeam': {'id': 106, 'name': 'VERONA'},
#   'referee': {'id': 72, 'firstName': 'PAOLO', 'lastName': 'VALERI'},
#   'assistant1': {'id': 71,
#    'firstName': 'ALESSANDRO',
#    'lastName': 'GIALLATINI'},
#   'assistant2': {'id': 123, 'firstName': 'FABIANO', 'lastName': 'PRETI'},
#   'fourth': {'id': 866, 'firstName': None, 'lastName': 'VOLPI'},
#   'var': {'id': 36, 'firstName': 'MAURIZIO', 'lastName': 'MARIANI'},
#   'avar': {'id': 1036, 'firstName': 'ORESTE', 'lastName': 'MUTO'},
#   'homeScore': '3',
#   'awayScore': '1'},
#  {'id': 34328,
#   'date': '2023-05-28 20:45:00',
#   'matchday': 37,
#   'season': {'id': 2022, 'name': '2022-2023'},
#   'competition': {'id': 2, 'name': 'SERIE A'},
#   'homeTeam': {'id': 108, 'name': 'JUVENTUS'},
#   'awayTeam': {'id': 100, 'name': 'MILAN'},
#   'referee': {'id': 36, 'firstName': 'MAURIZIO', 'lastName': 'MARIANI'},
#   'assistant1': {'id': 57, 'firstName': 'ALESSANDRO', 'lastName': 'COSTANZO'},
#   'assistant2': {'id': 87, 'firstName': 'MATTEO', 'lastName': 'PASSERI'},
#   'fourth': {'id': 802, 'firstName': None, 'lastName': 'MASSIMI'},
#   'var': {'id': 21, 'firstName': 'MASSIMILIANO', 'lastName': 'IRRATI'},
#   'avar': {'id': 285, 'firstName': None, 'lastName': 'PICCININI'},
#   'homeScore': '0',
#   'awayScore': '1'}]

# %%
## TROVA ALTRI PLAYER ID NELLO STESSO MATCH ID (DIVISO PER TEAM ID) ##

link = 'http://server.sics.it/livefeeds/x17.json?matchId='+str(matchId)+'&lang=it'

# JSON_dataMaking a get request
event_json_data = requests.get(link, auth = HTTPBasicAuth(username_, pwd_)).json()

if homeAwayFlag == 'HOME':
    team_player_ids = list(map(lambda row: row['id'], event_json_data['matchData']['homeTeam']['player']))
    opp_player_ids = list(map(lambda row: row['id'], event_json_data['matchData']['awayTeam']['player']))
else:
    team_player_ids = list(map(lambda row: row['id'], event_json_data['matchData']['awayTeam']['player']))
    opp_player_ids = list(map(lambda row: row['id'], event_json_data['matchData']['homeTeam']['player']))

team_player_ids
# Out:
# [21438,
#  7811,
#  23944,
#  18218,
#  15562,
#  14398,
#  8677,
#  14410,
#  14559,
#  20900,
#  7851,
#  7723,
#  22258,
#  9181,
#  17629,
#  20258]

# %%
# TEST: TROVA VARIABILI PER PLAYER ID NEL MATCH ID ##

player_match_link = ' http://server.sics.it/livefeeds/s04.json?fixtureId='+str(matchId)+'&playerId='+str(playerId)+'&lang=it'
player_match_json_data = requests.get(player_match_link, auth = HTTPBasicAuth(username_, pwd_)).json()

player_match_stats = player_match_json_data['playerStats']['fundamental']
descriptions_test = list(map(lambda c : c['description'], player_match_stats))

player_match_stats[:3]
# Out:
# [{'code': 'playTime',
#   'description': 'Minuti Giocati',
#   'value': '100',
#   'id': '1'},
#  {'code': 'passChiave',
#   'description': 'Passaggi Chiave',
#   'value': '6',
#   'id': '8'},
#  {'code': 'passChiaveInArea',
#   'description': 'Passaggi Chiave in Area',
#   'value': '2',
#   'id': '9'}]

# %%
descriptions_test[:3]
# Out:
# ['Minuti Giocati', 'Passaggi Chiave', 'Passaggi Chiave in Area']

# %%
## TROVA VARIABILI PER PLAYER ID DELLO STESSO TEAM ID NEL MATCH ID ##

def mergeTwoListsNoDuplicates(first_list,second_list):
    
    in_first = set(first_list)
    in_second = set(second_list)

    in_second_but_not_in_first = in_second - in_first

    result = first_list + list(in_second_but_not_in_first)

    return result

team_player_stats = {}
descriptions_list = []

for row_playerId in team_player_ids:
    
    # EVENTS PER PLAYER PER GAME
    team_player_stats[row_playerId] = {}
    player_match_link = ' http://server.sics.it/livefeeds/s04.json?fixtureId='+str(matchId)+'&playerId='+str(row_playerId)+'&lang=it'
    player_match_json_data = requests.get(player_match_link, auth = HTTPBasicAuth(username_, pwd_)).json()
    
    #player_json_data
    player_match_stats = player_match_json_data['playerStats']['fundamental']
    descriptions = list(map(lambda c : c['description'], player_match_stats))
    descriptions_list = mergeTwoListsNoDuplicates(descriptions_list,descriptions)
    
    for desc in descriptions:
        team_player_stats[row_playerId][desc] = float(list(filter(lambda a : a['description'] == desc, player_match_stats))[0]['value'])

# %%
team_player_stats[playerId]
#team_player_stats[7723]
# Out:
# {'Minuti Giocati': 100.0,
#  'Passaggi Chiave': 6.0,
#  'Passaggi Chiave in Area': 2.0,
#  'Passaggi': 94.0,
#  'Passaggi Riusciti': 80.0,
#  'Passaggi Ricevuti': 61.0,
#  'Giochi Portiere Ricevuti': 4.0,
#  'Assist': 2.0,
#  'Assist Vincenti': 1.0,
#  'Assist in Area': 2.0,
#  'Assist Vincenti in Area': 1.0,
#  'Third Pass': 1.0,
#  'Cross': 2.0,
#  'Cross Riusciti': 2.0,
#  'Cross Vincenti': 1.0,
#  'Traversoni': 1.0,
#  'Palle Laterali': 3.0,
#  'Palle Perse': 7.0,
#  'Triangolazioni': 1.0,
#  'Triangolazioni Chiuse': 1.0,
#  'Palle Recuperate': 10.0,
#  'Palle Perse Propria Meta Campo': 1.0,
#  'Palle Recuperate Meta Campo Avversaria': 1.0,
#  'Dribbling': 1.0,
#  'Dribbling Positivo': 1.0,
#  'Dribbling Subiti': 11.0,
#  'Dribbling Subiti Negativi': 5.0,
#  'Duelli': 18.0,
#  'Duelli Vinti su Falli di Gioco': 3.0,
#  'Duelli Vinti': 12.0,
#  'Duelli Vinti Meta Campo Offensiva': 2.0,
#  'Duelli Persi Meta Campo Offensiva': 1.0,
#  'Duelli Aerei': 1.0,
#  'Duelli Tackle': 2.0,
#  'Duelli Tackle Vinti': 2.0,
#  'Falli Subiti': 3.0,
#  'Gol Subiti': 2.0,
#  'Gol Procurati': 1.0}

# %%
descriptions_list
# Out:
# ['Tiri in Porta Subiti Parati',
#  'Passaggi Ricevuti',
#  'Lanci',
#  'Gol Subiti',
#  'Parate',
#  'Rinvii',
#  'Passaggi Chiave',
#  'Minuti Giocati',
#  'Passaggi Portiere Positivi',
#  'Rinvii di Mano',
#  'Parate di Mano',
#  'Lanci Positivi',
#  'Passaggi Riusciti',
#  'Passaggi',
#  'Passaggi Portiere',
#  'Uscite',
#  'Tiri in Porta Subiti',
#  'Gol Subiti dal Portiere',
#  'Third Pass',
#  'Dribbling',
#  'Duelli Aerei',
#  'Assist Vincenti',
#  'Duelli',
#  'Palle Recuperate',
#  'Cross Riusciti',
#  'Traversoni',
#  'Duelli Persi Meta Campo Offensiva',
#  'Palle Recuperate Meta Campo Avversaria',
#  'Passaggi Chiave in Area',
#  'Duelli Tackle Vinti',
#  'Palle Laterali',
#  'Duelli Vinti Meta Campo Offensiva',
#  'Assist',
#  'Dribbling Positivo',
#  'Assist Vincenti in Area',
#  'Duelli Vinti',
#  'Giochi Portiere Ricevuti',
#  'Triangolazioni',
#  'Palle Perse Propria Meta Campo',
#  'Assist in Area',
#  'Duelli Tackle',
#  'Gol Procurati',
#  'Cross Vincenti',
#  'Duelli Vinti su Falli di Gioco',
#  'Cross',
#  'Dribbling Subiti Negativi',
#  'Palle Perse',
#  'Falli Subiti',
#  'Triangolazioni Chiuse',
#  'Dribbling Subiti',
#  'Falli Fatti',
#  'Interventi Positivi',
#  'Duelli Aerei Vinti',
#  'Passaggi Chiave Ricevuti',
#  'Tiri da Area',
#  'Tiri in Porta da Area',
#  'Tiri Gol',
#  'Gol su Rigore',
#  'Tiri da Fuori',
#  'Tiri Gol da Area',
#  'Rigori',
#  'Tiri',
#  'Tiri in Porta',
#  'Tiri Gol di Piede',
#  'Ammonizioni',
#  'Passaggi Chiave Ricevuti in Area',
#  'Triangolazioni Fatte',
#  'Giochi Portiere Ricevuti Meta Campo Avversaria',
#  'Tiri da Area Piccola',
#  'Cut Back Vincenti',
#  'Tiri Gol da Area Piccola',
#  'Cut Back Riusciti',
#  'Cut Back']

# %%
## SCEGLIAMO VARIABILI SU CUI AZIONARE GLI INSIGHT ##

chosen_vars = {'Duelli': ['Duelli Vinti','Duelli','Duelli Tackle','Duelli Persi Meta Campo Offensiva','Duelli Vinti Meta Campo Offensiva','Palle Recuperate','Palle Recuperate Meta Campo Avversaria'],
               
               'Finalizzazione': ['Tiri','Tiri in Porta','Tiri Gol','Tiri di Testa','Tiri da Fuori','Assist','Assist Vincenti','Assist in Area','In Fuorigioco'],
               
               'Gioco': ['Passaggi','Passaggi Riusciti','Triangolazioni','Triangolazioni Fatte','Palle Perse','Palle Perse Propria Meta Campo','Giochi Portiere Ricevuti','Giochi Portiere Ricevuti Meta Campo Avversaria','Passaggi Chiave','Passaggi Chiave Ricevuti in Area','Dribbling','Dribbling Positivo','Third Pass','Third Pass Vincenti','Lanci','Lanci Positivi'],
               
               'Palle Laterali': ['Cut Back','Cut Back Riusciti','Cross','Cross Riusciti','Palle Laterali']}

chosen_vars
# Out:
# {'Duelli': ['Duelli Vinti',
#   'Duelli',
#   'Duelli Tackle',
#   'Duelli Persi Meta Campo Offensiva',
#   'Duelli Vinti Meta Campo Offensiva',
#   'Palle Recuperate',
#   'Palle Recuperate Meta Campo Avversaria'],
#  'Finalizzazione': ['Tiri',
#   'Tiri in Porta',
#   'Tiri Gol',
#   'Tiri di Testa',
#   'Tiri da Fuori',
#   'Assist',
#   'Assist Vincenti',
#   'Assist in Area',
#   'In Fuorigioco'],
#  'Gioco': ['Passaggi',
#   'Passaggi Riusciti',
#   'Triangolazioni',
#   'Triangolazioni Fatte',
#   'Palle Perse',
#   'Palle Perse Propria Meta Campo',
#   'Giochi Portiere Ricevuti',
#   'Giochi Portiere Ricevuti Meta Campo Avversaria',
#   'Passaggi Chiave',
#   'Passaggi Chiave Ricevuti in Area',
#   'Dribbling',
#   'Dribbling Positivo',
#   'Third Pass',
#   'Third Pass Vincenti',
#   'Lanci',
#   'Lanci Positivi'],
#  'Palle Laterali': ['Cut Back',
#   'Cut Back Riusciti',
#   'Cross',
#   'Cross Riusciti',
#   'Palle Laterali']}

# %%
## CREIAMO VARIABILI COMPLESSE SU CUI AZIONARE GLI INSIGHT ##

def createNewMetric(num,den,lista):
    
    try:
        num = float(lista[num])
    except:
        num = 0.0
        
    try:
        den = float(lista[den])
    except:
        den = 0.0

    if den == 0.0:
        return None
    else:
        return round(100*(num/den),1)

var_list_to_add= [['passRiusciti_PERC','Passaggi Riusciti','Passaggi'],
                  ['duelliVinti_PERC','Duelli Vinti','Duelli'],
                  ['duelliAerei_PERC','Duelli Aerei Vinti','Duelli Aerei'],
                 ]

chosen_vars['Percentuali'] = []

for var_row in var_list_to_add:
    new_var = createNewMetric(var_row[1],var_row[2],team_player_stats[playerId])
    if  new_var != None:
        team_player_stats[playerId][var_row[0]] = new_var
    else:
        pass
        
    chosen_vars['Percentuali'].append(var_row[0])

team_player_stats[playerId]
# Out:
# {'Minuti Giocati': 100.0,
#  'Passaggi Chiave': 6.0,
#  'Passaggi Chiave in Area': 2.0,
#  'Passaggi': 94.0,
#  'Passaggi Riusciti': 80.0,
#  'Passaggi Ricevuti': 61.0,
#  'Giochi Portiere Ricevuti': 4.0,
#  'Assist': 2.0,
#  'Assist Vincenti': 1.0,
#  'Assist in Area': 2.0,
#  'Assist Vincenti in Area': 1.0,
#  'Third Pass': 1.0,
#  'Cross': 2.0,
#  'Cross Riusciti': 2.0,
#  'Cross Vincenti': 1.0,
#  'Traversoni': 1.0,
#  'Palle Laterali': 3.0,
#  'Palle Perse': 7.0,
#  'Triangolazioni': 1.0,
#  'Triangolazioni Chiuse': 1.0,
#  'Palle Recuperate': 10.0,
#  'Palle Perse Propria Meta Campo': 1.0,
#  'Palle Recuperate Meta Campo Avversaria': 1.0,
#  'Dribbling': 1.0,
#  'Dribbling Positivo': 1.0,
#  'Dribbling Subiti': 11.0,
#  'Dribbling Subiti Negativi': 5.0,
#  'Duelli': 18.0,
#  'Duelli Vinti su Falli di Gioco': 3.0,
#  'Duelli Vinti': 12.0,
#  'Duelli Vinti Meta Campo Offensiva': 2.0,
#  'Duelli Persi Meta Campo Offensiva': 1.0,
#  'Duelli Aerei': 1.0,
#  'Duelli Tackle': 2.0,
#  'Duelli Tackle Vinti': 2.0,
#  'Falli Subiti': 3.0,
#  'Gol Subiti': 2.0,
#  'Gol Procurati': 1.0,
#  'passRiusciti_PERC': 85.1,
#  'duelliVinti_PERC': 66.7,
#  'duelliAerei_PERC': 0.0}

# %%
chosen_vars
# Out:
# {'Duelli': ['Duelli Vinti',
#   'Duelli',
#   'Duelli Tackle',
#   'Duelli Persi Meta Campo Offensiva',
#   'Duelli Vinti Meta Campo Offensiva',
#   'Palle Recuperate',
#   'Palle Recuperate Meta Campo Avversaria'],
#  'Finalizzazione': ['Tiri',
#   'Tiri in Porta',
#   'Tiri Gol',
#   'Tiri di Testa',
#   'Tiri da Fuori',
#   'Assist',
#   'Assist Vincenti',
#   'Assist in Area',
#   'In Fuorigioco'],
#  'Gioco': ['Passaggi',
#   'Passaggi Riusciti',
#   'Triangolazioni',
#   'Triangolazioni Fatte',
#   'Palle Perse',
#   'Palle Perse Propria Meta Campo',
#   'Giochi Portiere Ricevuti',
#   'Giochi Portiere Ricevuti Meta Campo Avversaria',
#   'Passaggi Chiave',
#   'Passaggi Chiave Ricevuti in Area',
#   'Dribbling',
#   'Dribbling Positivo',
#   'Third Pass',
#   'Third Pass Vincenti',
#   'Lanci',
#   'Lanci Positivi'],
#  'Palle Laterali': ['Cut Back',
#   'Cut Back Riusciti',
#   'Cross',
#   'Cross Riusciti',
#   'Palle Laterali'],
#  'Percentuali': ['passRiusciti_PERC', 'duelliVinti_PERC', 'duelliAerei_PERC']}

# %%
## TROVA I DATI STAGIONALI PER PLAYER ID ##

player_link = ' http://server.sics.it/livefeeds/s05.json?playerId='+str(playerId)+'&lang=it'
seasonal_player_json_data = requests.get(player_link, auth = HTTPBasicAuth(username_, pwd_)).json()

seasonal_fundamental_stats = seasonal_player_json_data['seasonPlayerStats']['fundamental']

seasonal_fundamental_stats[:7]
# Out:
# [{'code': 'playTime',
#   'description': 'Minuti Giocati',
#   'value': '1814',
#   'id': '1'},
#  {'code': 'playTime_MEAN',
#   'description': 'Minuti Giocati',
#   'avg': True,
#   'value': '73',
#   'id': '1a'},
#  {'code': 'tiri', 'description': 'Tiri', 'value': '12', 'id': '2'},
#  {'code': 'tiri_MEAN',
#   'description': 'Tiri',
#   'avg': True,
#   'value': '0.48',
#   'id': '2a'},
#  {'code': 'tiriInPorta',
#   'description': 'Tiri in Porta',
#   'value': '3',
#   'id': '3'},
#  {'code': 'tiriInPorta_PERC',
#   'description': 'Tiri in Porta',
#   'perc': True,
#   'value': '25.00%',
#   'id': '3p'},
#  {'code': 'tiriInPorta_MEAN',
#   'description': 'Tiri in Porta',
#   'avg': True,
#   'value': '0.12',
#   'id': '3a'}]

# %%
## SEPARA LE MEDIE STAGIONALI PER PLAYER ID ##

player_means = list(filter(lambda row : '_MEAN' in str(row['code']), seasonal_fundamental_stats))
player_means[:5]
# Out:
# [{'code': 'playTime_MEAN',
#   'description': 'Minuti Giocati',
#   'avg': True,
#   'value': '73',
#   'id': '1a'},
#  {'code': 'tiri_MEAN',
#   'description': 'Tiri',
#   'avg': True,
#   'value': '0.48',
#   'id': '2a'},
#  {'code': 'tiriInPorta_MEAN',
#   'description': 'Tiri in Porta',
#   'avg': True,
#   'value': '0.12',
#   'id': '3a'},
#  {'code': 'tiriDaArea_MEAN',
#   'description': 'Tiri da Area',
#   'avg': True,
#   'value': '0.16',
#   'id': '4a'},
#  {'code': 'tiriDaFuori_MEAN',
#   'description': 'Tiri da Fuori',
#   'avg': True,
#   'value': '0.32',
#   'id': '5a'}]

# %%
## SEPARA LE PERCENTUALI STAGIONALI PER PLAYER ID ##

player_percentages = list(filter(lambda d : '_PERC' in str(d['code']), seasonal_fundamental_stats))
player_percentages[:5]
# Out:
# [{'code': 'tiriInPorta_PERC',
#   'description': 'Tiri in Porta',
#   'perc': True,
#   'value': '25.00%',
#   'id': '3p'},
#  {'code': 'tiriDaArea_PERC',
#   'description': 'Tiri da Area',
#   'perc': True,
#   'value': '33.33%',
#   'id': '4p'},
#  {'code': 'tiriDaFuori_PERC',
#   'description': 'Tiri da Fuori',
#   'perc': True,
#   'value': '66.67%',
#   'id': '5p'},
#  {'code': 'tiriDiTesta_PERC',
#   'description': 'Tiri di Testa',
#   'perc': True,
#   'value': '16.67%',
#   'id': '6p'},
#  {'code': 'passChiaveInArea_PERC',
#   'description': 'Passaggi Chiave in Area',
#   'perc': True,
#   'value': '26.42%',
#   'id': '9p'}]

# %%
team_player_ids
# Out:
# [21438,
#  7811,
#  23944,
#  18218,
#  15562,
#  14398,
#  8677,
#  14410,
#  14559,
#  20900,
#  7851,
#  7723,
#  22258,
#  9181,
#  17629,
#  20258]

# %%
def findInsightBasedOnSeasonal_(match_value, avg_season_value):

    if avg_season_value > 0:
        return float(np.round(100*((match_value-avg_season_value)/avg_season_value),1))
    else:
        return -9999

def trySingleDescForPlayer(player_list, desc):

    if desc in player_list.keys():
        return player_list[desc]
    else:
        return 0.0

def positionForDescAmongOtherPlayers(desc,match_value_,list_to_compare):
    
    values_for_team_players = list(map(lambda playerId : trySingleDescForPlayer(team_player_stats[playerId],desc), team_player_ids))

    higher_than_match_value = list(filter(lambda value: value > match_value_, values_for_team_players))
    
    return len(higher_than_match_value)+1

# %%
positionForDescAmongOtherPlayers('Duelli Vinti',4.0,team_player_ids)
# Out:
# 7

# %%
chosen_vars['Duelli']
# Out:
# ['Duelli Vinti',
#  'Duelli',
#  'Duelli Tackle',
#  'Duelli Persi Meta Campo Offensiva',
#  'Duelli Vinti Meta Campo Offensiva',
#  'Palle Recuperate',
#  'Palle Recuperate Meta Campo Avversaria']

# %%
team_player_stats[playerId]
# Out:
# {'Minuti Giocati': 100.0,
#  'Passaggi Chiave': 6.0,
#  'Passaggi Chiave in Area': 2.0,
#  'Passaggi': 94.0,
#  'Passaggi Riusciti': 80.0,
#  'Passaggi Ricevuti': 61.0,
#  'Giochi Portiere Ricevuti': 4.0,
#  'Assist': 2.0,
#  'Assist Vincenti': 1.0,
#  'Assist in Area': 2.0,
#  'Assist Vincenti in Area': 1.0,
#  'Third Pass': 1.0,
#  'Cross': 2.0,
#  'Cross Riusciti': 2.0,
#  'Cross Vincenti': 1.0,
#  'Traversoni': 1.0,
#  'Palle Laterali': 3.0,
#  'Palle Perse': 7.0,
#  'Triangolazioni': 1.0,
#  'Triangolazioni Chiuse': 1.0,
#  'Palle Recuperate': 10.0,
#  'Palle Perse Propria Meta Campo': 1.0,
#  'Palle Recuperate Meta Campo Avversaria': 1.0,
#  'Dribbling': 1.0,
#  'Dribbling Positivo': 1.0,
#  'Dribbling Subiti': 11.0,
#  'Dribbling Subiti Negativi': 5.0,
#  'Duelli': 18.0,
#  'Duelli Vinti su Falli di Gioco': 3.0,
#  'Duelli Vinti': 12.0,
#  'Duelli Vinti Meta Campo Offensiva': 2.0,
#  'Duelli Persi Meta Campo Offensiva': 1.0,
#  'Duelli Aerei': 1.0,
#  'Duelli Tackle': 2.0,
#  'Duelli Tackle Vinti': 2.0,
#  'Falli Subiti': 3.0,
#  'Gol Subiti': 2.0,
#  'Gol Procurati': 1.0,
#  'passRiusciti_PERC': 85.1,
#  'duelliVinti_PERC': 66.7,
#  'duelliAerei_PERC': 0.0}

# %%
## CALCOLA VALORI PER GLI INSIGHT ##

insight_based_on_seasonal = []

for main_desc in chosen_vars.keys():
    
    for desc in chosen_vars[main_desc]:

        #print(desc)
        
        if desc in team_player_stats[playerId].keys():
            match_value_ = float(team_player_stats[playerId][desc])
        else:
            match_value_ = 0.0

        #print(match_value_)

        position_among_team_players = positionForDescAmongOtherPlayers(desc,match_value_,team_player_ids)

        #print(position_among_team_players)

        if 'PERC' in desc:
            try:
                avg_season_value_ = list(filter(lambda a : a['code'] == desc, player_percentages))[0]['value']
                float_avg_season_value_ =  float(avg_season_value_.replace('%',''))
            except:
                float_avg_season_value_ = 0.0
        else:
            try:
                float_avg_season_value_ = float(list(filter(lambda a : a['description'] == desc, player_means))[0]['value'])
            except:
                float_avg_season_value_ = 0.0
    
        #print(float_avg_season_value_)
    
        insight_based_on_seasonal.append([main_desc,desc,match_value_,float_avg_season_value_,position_among_team_players,findInsightBasedOnSeasonal_(match_value_,float_avg_season_value_)])
    
        #print(insight_based_on_seasonal)

# %%
insight_based_on_seasonal
# Out:
# [['Duelli', 'Duelli Vinti', 12.0, 6.2, 1, 93.5],
#  ['Duelli', 'Duelli', 18.0, 10.84, 1, 66.1],
#  ['Duelli', 'Duelli Tackle', 2.0, 3.76, 9, -46.8],
#  ['Duelli', 'Duelli Persi Meta Campo Offensiva', 1.0, 1.56, 11, -35.9],
#  ['Duelli', 'Duelli Vinti Meta Campo Offensiva', 2.0, 2.48, 4, -19.4],
#  ['Duelli', 'Palle Recuperate', 10.0, 5.68, 1, 76.1],
#  ['Duelli', 'Palle Recuperate Meta Campo Avversaria', 1.0, 1.6, 4, -37.5],
#  ['Finalizzazione', 'Tiri', 0.0, 0.48, 7, -100.0],
#  ['Finalizzazione', 'Tiri in Porta', 0.0, 0.12, 4, -100.0],
#  ['Finalizzazione', 'Tiri Gol', 0.0, 0.04, 4, -100.0],
#  ['Finalizzazione', 'Tiri di Testa', 0.0, 0.08, 1, -100.0],
#  ['Finalizzazione', 'Tiri da Fuori', 0.0, 0.32, 5, -100.0],
#  ['Finalizzazione', 'Assist', 2.0, 0.6, 1, 233.3],
#  ['Finalizzazione', 'Assist Vincenti', 1.0, 0.16, 1, 525.0],
#  ['Finalizzazione', 'Assist in Area', 2.0, 0.44, 1, 354.5],
#  ['Finalizzazione', 'In Fuorigioco', 0.0, 0.04, 1, -100.0],
#  ['Gioco', 'Passaggi', 94.0, 50.0, 1, 88.0],
#  ['Gioco', 'Passaggi Riusciti', 80.0, 43.12, 1, 85.5],
#  ['Gioco', 'Triangolazioni', 1.0, 0.4, 1, 150.0],
#  ['Gioco', 'Triangolazioni Fatte', 0.0, 0.16, 3, -100.0],
#  ['Gioco', 'Palle Perse', 7.0, 4.36, 3, 60.6],
#  ['Gioco', 'Palle Perse Propria Meta Campo', 1.0, 0.92, 3, 8.7],
#  ['Gioco', 'Giochi Portiere Ricevuti', 4.0, 2.16, 1, 85.2],
#  ['Gioco',
#   'Giochi Portiere Ricevuti Meta Campo Avversaria',
#   0.0,
#   0.08,
#   4,
#   -100.0],
#  ['Gioco', 'Passaggi Chiave', 6.0, 2.12, 1, 183.0],
#  ['Gioco', 'Passaggi Chiave Ricevuti in Area', 0.0, 0.24, 5, -100.0],
#  ['Gioco', 'Dribbling', 1.0, 0.76, 9, 31.6],
#  ['Gioco', 'Dribbling Positivo', 1.0, 0.56, 5, 78.6],
#  ['Gioco', 'Third Pass', 1.0, 0.04, 1, 2400.0],
#  ['Gioco', 'Third Pass Vincenti', 0.0, 0.0, 1, -9999],
#  ['Gioco', 'Lanci', 0.0, 0.0, 2, -9999],
#  ['Gioco', 'Lanci Positivi', 0.0, 0.0, 2, -9999],
#  ['Palle Laterali', 'Cut Back', 0.0, 0.08, 2, -100.0],
#  ['Palle Laterali', 'Cut Back Riusciti', 0.0, 0.0, 2, -9999],
#  ['Palle Laterali', 'Cross', 2.0, 1.28, 2, 56.2],
#  ['Palle Laterali', 'Cross Riusciti', 2.0, 0.68, 1, 194.1],
#  ['Palle Laterali', 'Palle Laterali', 3.0, 1.56, 1, 92.3],
#  ['Percentuali', 'passRiusciti_PERC', 85.1, 86.24, 1, -1.3],
#  ['Percentuali', 'duelliVinti_PERC', 66.7, 57.2, 1, 16.6],
#  ['Percentuali', 'duelliAerei_PERC', 0.0, 11.07, 1, -100.0]]

# %%
## CREAZIONE INSIGHT TESTUALI ##

description_index = 1
match_value_index = 2
average_index = 3
position_among_team_players_index = 4
match_value_wrt_average_index = -1

insight_variation_minimum = 20

def perc_sign(perc_variation):

    if perc_variation < 0:
        return str(perc_variation)
    else:
        return '+'+str(perc_variation)
        
for main_desc in chosen_vars.keys():

    print ('INSIGHT - '+str(main_desc))
    print (' ')
    rows = list(filter(lambda a : (a[0] == main_desc), insight_based_on_seasonal))

    tops = sorted(list(filter(lambda a : (a[match_value_wrt_average_index] > insight_variation_minimum) and (a[match_value_index] > 1), rows)), key = itemgetter(match_value_wrt_average_index), reverse = True)

    print('SOPRA LA MEDIA')
    print (' ')
    
    if len(tops) > 0:
        
        for single_row in tops:
            print(single_row[description_index]+' : '+str(single_row[match_value_index])
                  +' ('+perc_sign(single_row[match_value_wrt_average_index])+'%) rispetto alla media di '+str(single_row[average_index])+", "
                 +str(single_row[position_among_team_players_index])+"° in squadra"
                 )
    
        print (' ')
    
    else:
        print('Nessuno')
        print(' ')
        
    flops = sorted(list(filter(lambda a : (a[match_value_wrt_average_index] < -insight_variation_minimum) and (a[match_value_wrt_average_index] > -9999), rows)), key = itemgetter(match_value_wrt_average_index))
    print('SOTTO LA MEDIA')
    print (' ')
    
    if len(flops) > 0:
        
        for single_row in flops:
            print(single_row[description_index]+' : '+str(single_row[match_value_index])+' ('+perc_sign(single_row[match_value_wrt_average_index])+'%) rispetto alla media di '+str(single_row[average_index])+", "
                 +str(single_row[position_among_team_players_index])+"° in squadra"
                 )
        print (' ')
    
    else:
        print('Nessuno')
        print (' ')
# Out:
# INSIGHT - Duelli
#
# SOPRA LA MEDIA
#
# Duelli Vinti : 12.0 (+93.5%) rispetto alla media di 6.2, 1° in squadra
# Palle Recuperate : 10.0 (+76.1%) rispetto alla media di 5.68, 1° in squadra
# Duelli : 18.0 (+66.1%) rispetto alla media di 10.84, 1° in squadra
#
# SOTTO LA MEDIA
#
# Duelli Tackle : 2.0 (-46.8%) rispetto alla media di 3.76, 9° in squadra
# Palle Recuperate Meta Campo Avversaria : 1.0 (-37.5%) rispetto alla media di 1.6, 4° in squadra
# Duelli Persi Meta Campo Offensiva : 1.0 (-35.9%) rispetto alla media di 1.56, 11° in squadra
#
# INSIGHT - Finalizzazione
#
# SOPRA LA MEDIA
#
# Assist in Area : 2.0 (+354.5%) rispetto alla media di 0.44, 1° in squadra
# Assist : 2.0 (+233.3%) rispetto alla media di 0.6, 1° in squadra
#
# SOTTO LA MEDIA
#
# Tiri : 0.0 (-100.0%) rispetto alla media di 0.48, 7° in squadra
# Tiri in Porta : 0.0 (-100.0%) rispetto alla media di 0.12, 4° in squadra
# Tiri Gol : 0.0 (-100.0%) rispetto alla media di 0.04, 4° in squadra
# Tiri di Testa : 0.0 (-100.0%) rispetto alla media di 0.08, 1° in squadra
# Tiri da Fuori : 0.0 (-100.0%) rispetto alla media di 0.32, 5° in squadra
# In Fuorigioco : 0.0 (-100.0%) rispetto alla media di 0.04, 1° in squadra
#
# INSIGHT - Gioco
#
# SOPRA LA MEDIA
#
# Passaggi Chiave : 6.0 (+183.0%) rispetto alla media di 2.12, 1° in squadra
# Passaggi : 94.0 (+88.0%) rispetto alla media di 50.0, 1° in squadra
# Passaggi Riusciti : 80.0 (+85.5%) rispetto alla media di 43.12, 1° in squadra
# Giochi Portiere Ricevuti : 4.0 (+85.2%) rispetto alla media di 2.16, 1° in squadra
# Palle Perse : 7.0 (+60.6%) rispetto alla media di 4.36, 3° in squadra
#
# SOTTO LA MEDIA
#
# Triangolazioni Fatte : 0.0 (-100.0%) rispetto alla media di 0.16, 3° in squadra
# Giochi Portiere Ricevuti Meta Campo Avversaria : 0.0 (-100.0%) rispetto alla media di 0.08, 4° in squadra
# Passaggi Chiave Ricevuti in Area : 0.0 (-100.0%) rispetto alla media di 0.24, 5° in squadra
#
# INSIGHT - Palle Laterali
#
# SOPRA LA MEDIA
#
# Cross Riusciti : 2.0 (+194.1%) rispetto alla media di 0.68, 1° in squadra
# Palle Laterali : 3.0 (+92.3%) rispetto alla media di 1.56, 1° in squadra
# Cross : 2.0 (+56.2%) rispetto alla media di 1.28, 2° in squadra
#
# SOTTO LA MEDIA
#
# Cut Back : 0.0 (-100.0%) rispetto alla media di 0.08, 2° in squadra
#
# INSIGHT - Percentuali
#
# SOPRA LA MEDIA
#
# Nessuno
#
# SOTTO LA MEDIA
#
# duelliAerei_PERC : 0.0 (-100.0%) rispetto alla media di 11.07, 1° in squadra

# %%
def avoidStringError(string):

    return str(string).replace('\n',' ')

def takeDescriptionFromList(item__,sub_item):

    try:
        new_list = list(map(lambda a : a[sub_item], item__))
        if len(new_list) == 1:
            return avoidStringError(new_list[0])
        else:
            return list(map(lambda d : avoidStringError(d), new_list))
    except:
        return None

def takeDescriptionFromDict(item__,sub_item):

    try:
        return avoidStringError(item__[sub_item])
    except:
        return None

def splitXY(item__,index_pos):

    try:
        return avoidStringError(str(item__).split(';')[index_pos])
    except:
        return None

event_json_data.keys()
# Out:
# dict_keys(['matchId', 'type', 'description', 'timestamp', 'matchData', 'event'])

# %%
event_json_data['event'][0]#['startPointNorm'].split(';')
# Out:
# {'team': {'id': 100, 'name': 'MILAN'},
#  'event': {'id': 4, 'description': 'Palle Inattive Contro'},
#  'tag': [{'id': 26, 'description': 'Calcio Inizio'}],
#  'period': {'id': 1, 'description': '1t'},
#  'startMinute': 0,
#  'startSecond': 0,
#  'endMinute': 0,
#  'endSecond': 23,
#  'idEvent': 'PIC13082022205032as'}

# %%
## TROVA SINGOLI EVENTI PER MATCH ID ##

df = pd.DataFrame(event_json_data['event'])

df.head()
# Out:
#                              team  \
# 0    {'id': 100, 'name': 'MILAN'}
# 1  {'id': 115, 'name': 'UDINESE'}
# 2  {'id': 115, 'name': 'UDINESE'}
# 3  {'id': 115, 'name': 'UDINESE'}
# 4  {'id': 115, 'name': 'UDINESE'}
#
#                                                event  \
# 0  {'id': 4, 'description': 'Palle Inattive Contro'}
# 1           {'id': 267, 'description': 'Conduzione'}
# 2             {'id': 34, 'description': 'Passaggio'}
# 3             {'id': 34, 'description': 'Passaggio'}
# 4          {'id': 10, 'description': 'Perde
# Palla'}
#
#                                             tag  \
# 0  [{'id': 26, 'description': 'Calcio Inizio'}]
# 1                                            []
# 2      [{'id': 416, 'description': 'Riuscito'}]
# 3      [{'id': 416, 'description': 'Riuscito'}]
# 4                                            []
#
#                            period  startMinute  startSecond  endMinute  \
# 0  {'id': 1, 'description': '1t'}            0            0          0
# 1  {'id': 1, 'description': '1t'}            0            0          0
# 2  {'id': 1, 'description': '1t'}            0            0          0
# 3  {'id': 1, 'description': '1t'}            0            0          0
# 4  {'id': 1, 'description': '1t'}            0            0          0
#
#    endSecond              idEvent  \
# 0         23  PIC13082022205032as
# 1         11  COND1660425318971-1
# 2          7    PASS1660425318971
# 3         10  PASS1660425318971-0
# 4         10   PER1660425318971-3
#
#                                           playerFrom   startPoint  \
# 0                                                NaN          NaN
# 1  [{'id': 5565, 'firstName': 'ADAM', 'lastName':...   33.00;2.90
# 2  [{'id': 11335, 'firstName': 'WALACE', 'lastNam...  52.30;34.10
# 3  [{'id': 25529, 'firstName': 'NEHUEN', 'lastNam...  34.20;23.70
# 4  [{'id': 5565, 'firstName': 'ADAM', 'lastName':...  88.00;14.70
#
#       endPoint startPointNorm endPointNorm  \
# 0          NaN            NaN          NaN
# 1  88.00;14.70     33.00;2.90  88.00;14.70
# 2  34.20;23.70    52.30;34.10  34.20;23.70
# 3   33.00;2.90    34.20;23.70   33.00;2.90
# 4          NaN    88.00;14.70          NaN
#
#                                             playerTo result intersectionPoint  \
# 0                                                NaN    NaN               NaN
# 1                                                NaN    NaN               NaN
# 2  {'id': 25529, 'firstName': 'NEHUEN', 'lastName...    NaN               NaN
# 3  {'id': 5565, 'firstName': 'ADAM', 'lastName': ...    NaN               NaN
# 4                                                NaN    NaN               NaN
#
#   intersectionPointNorm
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
## RIFINISCI DATAFRAME EVENTI ##

df['team_id'] = df.apply(lambda row: takeDescriptionFromDict(row.team, 'id'), axis = 1)
df['team_name'] = df.apply(lambda row: takeDescriptionFromDict(row.team, 'name'), axis = 1)

df['event'] = df.apply(lambda row: takeDescriptionFromDict(row.event, 'description'), axis = 1)
df['tag'] = df.apply(lambda row: takeDescriptionFromList(row.tag, 'description'), axis = 1)
df['period'] = df.apply(lambda row: takeDescriptionFromDict(row.period, 'description'), axis = 1)

df['player_id'] = df.apply(lambda row: takeDescriptionFromList(row.playerFrom, 'id'), axis = 1)
df['player_first_name'] = df.apply(lambda row: takeDescriptionFromList(row.playerFrom, 'firstName'), axis = 1)
df['player_last_name'] = df.apply(lambda row: takeDescriptionFromList(row.playerFrom, 'lastName'), axis = 1)
df['player_name'] = df['player_first_name']+' '+ df['player_last_name']

df['player_to_id'] = df.apply(lambda row: takeDescriptionFromDict(row.playerTo, 'id'), axis = 1)
df['player_to_first_name'] = df.apply(lambda row: takeDescriptionFromDict(row.playerTo, 'firstName'), axis = 1)
df['player_to_last_name'] = df.apply(lambda row: takeDescriptionFromDict(row.playerTo, 'lastName'), axis = 1)
df['player_to_name'] = df['player_to_first_name']+' '+ df['player_to_last_name']

df['start_x'] = df.apply(lambda row: splitXY(row.startPointNorm, 0), axis = 1)
df['start_y'] = df.apply(lambda row: splitXY(row.startPointNorm, 1), axis = 1)

df['end_x'] = df.apply(lambda row: splitXY(row.endPointNorm, 0), axis = 1)
df['end_y'] = df.apply(lambda row: splitXY(row.endPointNorm, 1), axis = 1)

df = df.drop(columns = ['team',
                        'player_first_name','player_last_name','playerFrom',
                        'player_to_first_name','player_to_last_name','playerTo',
                        'startPoint','endPoint','startPointNorm','endPointNorm',
                        'intersectionPoint','intersectionPointNorm'])

# %%
df[df['startMinute'].isin([9,10])].sort_values(by = ['startMinute','startSecond'])
# Out:
#                       event                                          tag  \
# 1497              Passaggio                                     Riuscito
# 1498             Conduzione                                           []
# 1499             Conduzione                                           []
# 1500              Passaggio                                     Riuscito
# 1501           Perde  Palla                                           []
# 1502                  Fallo                          [Mano, Perde Palla]
# 1503              Passaggio                                     Riuscito
# 1504              Passaggio                                     Riuscito
# 1505             Conduzione                                           []
# 1506              Passaggio                                     Riuscito
# 1507           Perde  Palla                                           []
# 1508              Passaggio                                     Riuscito
# 1509             Conduzione                                           []
# 1510              Passaggio                                     Riuscito
# 1511              Passaggio                                    Impreciso
# 1512         Recupera Palla                                           []
# 1513          Duello  Vinto                    [Dribbling, Non Recupera]
# 1514              Dribbling                                           []
# 1515          Duello  Perso                       [Dribbling, Non Perde]
# 1516      Dribbling  Subito                                           []
# 1517          Duello  Vinto               [Fallo di Gioco, Non Recupera]
# 1518          Fallo  Subito                                        Gioco
# 1519          Duello  Perso                  [Fallo di Gioco, Non Perde]
# 1520                  Fallo                                        Gioco
# 1521            Ammonizione                               Fallo di Gioco
# 1522  Palle Inattive Favore                           Punizione Laterale
# 1523  Palle Inattive Contro                           Punizione Laterale
# 1524              Passaggio                                    Impreciso
# 203   Palle Inattive Favore                     [Azione di Rigore, Rete]
# 204             Rete  Fatta          [Sinistro, Rigore, In Area, Rigore]
# 205             Tiro  Fatto  [Rete, Sinistro, Rigore, In Area, In Porta]
# 206   Palle Inattive Contro                     [Azione di Rigore, Rete]
# 207            Rete  Subita          [Sinistro, Rigore, In Area, Rigore]
# 208            Tiro  Subito  [Rete, Sinistro, Rigore, In Area, In Porta]
#
#      period  startMinute  startSecond  endMinute  endSecond  \
# 1497     2t            9            1          9         11
# 1498     2t            9            2          9         13
# 1499     2t            9            4          9         15
# 1500     2t            9            4          9         14
# 1501     2t            9            6          9         18
# 1502     2t            9            7          9         19
# 1503     2t            9            7          9         17
# 1504     2t            9            8          9         18
# 1505     2t            9           23          9         34
# 1506     2t            9           23          9         33
# 1507     2t            9           26          9         38
# 1508     2t            9           27          9         37
# 1509     2t            9           28          9         39
# 1510     2t            9           28          9         38
# 1511     2t            9           30          9         40
# 1512     2t            9           31          9         43
# 1513     2t            9           32          9         44
# 1514     2t            9           32          9         44
# 1515     2t            9           32          9         44
# 1516     2t            9           32          9         44
# 1517     2t            9           33          9         45
# 1518     2t            9           33          9         45
# 1519     2t            9           33          9         45
# 1520     2t            9           33          9         45
# 1521     2t            9           34          9         41
# 1522     2t           10           48         10         56
# 1523     2t           10           48         10         56
# 1524     2t           10           50         11          0
# 203      1t           10           56         11         37
# 204      1t           10           56         11         37
# 205      1t           10           56         11         37
# 206      1t           10           56         11         37
# 207      1t           10           56         11         37
# 208      1t           10           56         11         37
#
#                     idEvent result team_id team_name player_id  \
# 1497   PASS1660425318984-60    NaN     100     MILAN     23944
# 1498   COND1660425318984-61    NaN     100     MILAN     18218
# 1499   COND1660425318984-63    NaN     100     MILAN     14398
# 1500   PASS1660425318984-62    NaN     100     MILAN     18218
# 1501    PER1660425318984-66    NaN     100     MILAN     14559
# 1502    FAF1660425318984-67    NaN     100     MILAN     14559
# 1503   PASS1660425318984-64    NaN     100     MILAN     14398
# 1504   PASS1660425318984-65    NaN     100     MILAN      7851
# 1505   COND1660425318984-69    NaN     115   UDINESE      6130
# 1506   PASS1660425318984-68    NaN     115   UDINESE     20899
# 1507    PER1660425318984-74    NaN     115   UDINESE      6130
# 1508   PASS1660425318984-70    NaN     115   UDINESE      6130
# 1509   COND1660425318984-72    NaN     115   UDINESE      6130
# 1510   PASS1660425318984-71    NaN     115   UDINESE     11335
# 1511   PASS1660425318984-73    NaN     115   UDINESE      6130
# 1512    REC1660425318984-75    NaN     100     MILAN     14410
# 1513    DLL1660425318984-76    NaN     100     MILAN     14410
# 1514    DRF1660425318984-76    POS     100     MILAN     14410
# 1515    DLS1660425318984-76    NaN     115   UDINESE     25529
# 1516  DRS1660425318984-76as    NEG     115   UDINESE     25529
# 1517  DLL1660425318984-77as    NaN     100     MILAN     14410
# 1518  FAS1660425318984-77as    NaN     100     MILAN     14410
# 1519  DLS1660425318984-77as    NaN     115   UDINESE     25529
# 1520    FAF1660425318984-77    NaN     115   UDINESE     25529
# 1521      AMM13082022214810    NaN     115   UDINESE     25529
# 1522      PIF13082022214840    NaN     100     MILAN     14410
# 1523    PIC13082022214840as    NaN     115   UDINESE      None
# 1524   PASS1660425318984-78    NaN     100     MILAN     14410
# 203       PIF13082022210125    NaN     100     MILAN     15562
# 204       RTF13082022210135    NaN     100     MILAN     15562
# 205       TIF13082022210127    NaN     100     MILAN     15562
# 206     PIC13082022210125as    NaN     115   UDINESE      None
# 207     RTS13082022210135as    NaN     115   UDINESE     14079
# 208     TIS13082022210127as    NaN     115   UDINESE      None
#
#                           player_name player_to_id      player_to_name  \
# 1497                    PIERRE KALULU        18218       FIKAYO TOMORI
# 1498                    FIKAYO TOMORI         None                 NaN
# 1499                  ISMAEL BENNACER         None                 NaN
# 1500                    FIKAYO TOMORI        14398     ISMAEL BENNACER
# 1501                      BRAHIM DIAZ         None                 NaN
# 1502                      BRAHIM DIAZ         None                 NaN
# 1503                  ISMAEL BENNACER         7851          ANTE REBIC
# 1504                       ANTE REBIC        14559         BRAHIM DIAZ
# 1505                  ROBERTO PEREYRA         None                 NaN
# 1506                    RODRIGO BECAO         6130     ROBERTO PEREYRA
# 1507                  ROBERTO PEREYRA         None                 NaN
# 1508                  ROBERTO PEREYRA        11335  WALACE SOUZA SILVA
# 1509                  ROBERTO PEREYRA         None                 NaN
# 1510               WALACE SOUZA SILVA         6130     ROBERTO PEREYRA
# 1511                  ROBERTO PEREYRA         None                 NaN
# 1512                   JUNIOR MESSIAS         None                 NaN
# 1513                   JUNIOR MESSIAS         None                 NaN
# 1514                   JUNIOR MESSIAS         None                 NaN
# 1515                     NEHUEN PEREZ         None                 NaN
# 1516                     NEHUEN PEREZ         None                 NaN
# 1517                   JUNIOR MESSIAS         None                 NaN
# 1518                   JUNIOR MESSIAS         None                 NaN
# 1519                     NEHUEN PEREZ         None                 NaN
# 1520                     NEHUEN PEREZ         None                 NaN
# 1521                     NEHUEN PEREZ         None                 NaN
# 1522                   JUNIOR MESSIAS         None                 NaN
# 1523                              NaN         None                 NaN
# 1524                   JUNIOR MESSIAS         None                 NaN
# 203   THEO BERNARD FRANCOIS HERNANDEZ         None                 NaN
# 204   THEO BERNARD FRANCOIS HERNANDEZ         None                 NaN
# 205   THEO BERNARD FRANCOIS HERNANDEZ         None                 NaN
# 206                               NaN         None                 NaN
# 207                   MARCO SILVESTRI         None                 NaN
# 208                               NaN         None                 NaN
#
#      start_x start_y   end_x  end_y
# 1497   49.60   29.00   56.40  11.20
# 1498   56.40   11.20   57.10  12.70
# 1499   64.00   26.60   63.80  20.80
# 1500   57.10   12.70   64.00  26.60
# 1501   75.30   31.90     nan   None
# 1502   75.30   31.90     nan   None
# 1503   63.80   20.80   75.40  16.10
# 1504   75.40   16.10   74.40  33.40
# 1505   37.60   57.50   41.50  64.10
# 1506   29.10   50.60   37.60  57.50
# 1507   20.20    9.80     nan   None
# 1508   41.50   64.10   39.50  52.90
# 1509   35.70   63.60   20.20   9.80
# 1510   39.50   52.90   35.70  63.60
# 1511   35.90   61.90   20.20   9.80
# 1512   84.80   58.20     nan   None
# 1513   90.60   56.00     nan   None
# 1514   90.60   56.00     nan   None
# 1515   14.40   12.00     nan   None
# 1516   14.40   12.00     nan   None
# 1517   92.50   56.50     nan   None
# 1518   92.50   56.50     nan   None
# 1519   12.50   11.50     nan   None
# 1520   12.50   11.50     nan   None
# 1521   13.80   11.16     nan   None
# 1522   92.38   56.84   97.38  38.33
# 1523   12.62   11.16    7.62  29.67
# 1524   95.60   55.30   98.80  37.00
# 203    93.70   33.61  104.61  31.77
# 204    93.70   33.74  105.00  31.70
# 205    93.70   33.74  105.00  31.70
# 206    11.30   34.39    0.39  36.23
# 207    11.30   34.26    0.00  36.30
# 208    11.30   34.26    0.00  36.30

# %%
## FILTRA SOLO EVENTI RIGUARDANTI PLAYER ID ##

df_playered = df[~df['player_name'].isna()]
df_playered_to = df[~df['player_to_name'].isna()]

player_stats_in_the_game = df_playered[df_playered['player_name'].str.contains(player_to_search)]
player_to_stats_in_the_game = df_playered_to[df_playered_to['player_to_name'].str.contains(player_to_search)]

player_from = player_stats_in_the_game[['event','player_name']].groupby(by = ['event']).count()
player_to = player_to_stats_in_the_game[['event','player_name','player_to_name']].groupby(by = ['event','player_name']).count()

#player_from = player_from[player_name.str.contains(player_to_search)]
#player_to = player_to[player_to_name.str.contains(player_to_search)]

# %%
player_stats_in_the_game

# %%
player_from

# %%
player_to
